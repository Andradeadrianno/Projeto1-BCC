# %% [markdown]
# <a href="https://colab.research.google.com/github/Andradeadrianno/Projeto1-BCC/blob/main/An%C3%A1lise_de_dados_Projeto_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Base de dados sobre as Escolas da cidade de São Paulo

# %%
pd.read_csv("https://drive.google.com/u/3/uc?id=1Quu4pq4EToFlQYpvyYQySeHMkl3QbBOy&export=download" , sep = ";")
# Out:
#      dre  codesc tipoesc  ...     latitude    longitude    database
# 0     BT     191    EMEF  ...  -23.612.237  -46.749.888  01/12/2019
# 1     BT     213    EMEI  ...  -23.611.929  -46.750.176  01/12/2019
# 2     BT     477    EMEF  ...  -23.602.076  -46.783.825  01/12/2019
# 3     BT   11924    EMEF  ...  -23.586.959  -46.801.039  01/12/2019
# 4     BT   14591    EMEI  ...  -23.586.339  -46.800.967  01/12/2019
# ...   ..     ...     ...  ...          ...          ...         ...
# 4905  SM  501468    MOVA  ...  -23.623.674  -46.489.887  01/12/2019
# 4906  SM  501507    MOVA  ...  -23.607.238   -4.650.539  01/12/2019
# 4907  SM  501513    MOVA  ...  -23.596.456  -46.490.716  01/12/2019
# 4908  SM  501576    MOVA  ...  -23.624.554  -46.448.039  01/12/2019
# 4909  SM  501581    MOVA  ...  -23.604.463  -46.640.239  01/12/2019
#
# [4910 rows x 34 columns]

# %%
import pandas as pd 
import matplotlib.pyplot as plt

dados = pd.read_csv('http://dados.prefeitura.sp.gov.br/dataset/8da55b0e-b385-4b54-9296-d0000014ddd5/resource/726e9bdc-fcaa-405f-a3e6-6fe3f1a54680/download/escolas122019.csv', sep=';')

dados = dados[['tipoesc', 'nomesc', 'ceu', 'diretoria', 'subpref','situacao','distrito', 'setor', 
       'fx_etaria', 'dt_criacao', 'ato_criacao', 'dom_criacao', 'dt_ini_conv',
       'dt_ini_func', 'dt_autoriza', 'dt_extintao', 'nome_ant', 'rede','latitude', 'longitude']]


escolas_ativas = dados['situacao'].value_counts().rename_axis('situacao').reset_index(name='quantidade')
quantidade_escolas_nan = dados['situacao'].isna().sum()


print(quantidade_escolas_nan)

# %% [markdown]
# # Filtrando apenas a coluna que exibe a data de criação de cada escola

# %%
dados [["dt_criacao"]]

# %% [markdown]
# # Qual o ano que foi criado mais escolas?

# %%
dados['ano_criacao'] =  pd.DatetimeIndex(dados['dt_criacao']).year

quantidade_de_escolas = dados['subpref'].value_counts()

#ano_mais_escolas['quantidade'].mean()
#ano_mais_escolas['quantidade'].max()

ano_mais_escolas = dados['ano_criacao'].value_counts().rename_axis('ano').reset_index(name='quantidade')

ano_mais_escolas.plot(x ='ano', y='quantidade', kind = 'scatter')	
# plt.show()
