# %% [markdown]
# <a href="https://colab.research.google.com/github/Andradeadrianno/Projeto1-BCC/blob/main/Projeto_1_BCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Base de dados sobre as Escolas da cidade de São Paulo

# %%
import pandas as pd
df = pd.read_csv("https://drive.google.com/u/3/uc?id=1Quu4pq4EToFlQYpvyYQySeHMkl3QbBOy&export=download", sep=";")
df
# Out:
#      dre  codesc tipoesc  ...     latitude    longitude    database
# 0     BT     191    EMEF  ...  -23.612.237  -46.749.888  01/12/2019
# 1     BT     213    EMEI  ...  -23.611.929  -46.750.176  01/12/2019
# 2     BT     477    EMEF  ...  -23.602.076  -46.783.825  01/12/2019
# 3     BT   11924    EMEF  ...  -23.586.959  -46.801.039  01/12/2019
# 4     BT   14591    EMEI  ...  -23.586.339  -46.800.967  01/12/2019
# ...   ..     ...     ...  ...          ...          ...         ...
# 4905  SM  501468    MOVA  ...  -23.623.674  -46.489.887  01/12/2019
# 4906  SM  501507    MOVA  ...  -23.607.238   -4.650.539  01/12/2019
# 4907  SM  501513    MOVA  ...  -23.596.456  -46.490.716  01/12/2019
# 4908  SM  501576    MOVA  ...  -23.624.554  -46.448.039  01/12/2019
# 4909  SM  501581    MOVA  ...  -23.604.463  -46.640.239  01/12/2019
#
# [4910 rows x 34 columns]

# %% [markdown]
# # Data em que mais escolas foram criadas

# %% [markdown]
# Gráfico Número da escola pelo CEP

# %%
agrupamento = df.groupby("bairro").count ()
print (agrupamento)
# Out:
#                    dre  codesc  tipoesc  ...  latitude  longitude  database
# bairro                                   ...
# 55                   1       1        1  ...         1          1         1
# ACLIMACAO           10      10       10  ...        10         10        10
# AGUA BRANCA          4       4        4  ...         4          4         4
# AGUA FRIA            1       1        1  ...         1          1         1
# ALTO DA BOA VISTA    1       1        1  ...         1          1         1
# ...                ...     ...      ...  ...       ...        ...       ...
# VILA ZAT             4       4        4  ...         4          4         4
# VILA ZEFIRA          1       1        1  ...         1          1         1
# VILA ZELINA          2       2        2  ...         2          2         2
# ÁGUA BRANCA          5       5        5  ...         5          5         5
# ÁGUA FRIA            4       4        4  ...         4          4         4
#
# ...
